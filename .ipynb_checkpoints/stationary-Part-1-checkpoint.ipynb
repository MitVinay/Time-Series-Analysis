# %% [markdown]
# # Stationary Series

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller
import matplotlib.pyplot as plt
from pandas import Series
import numpy as np
from pandas import read_csv

# %% [markdown]
# ## Reading csv file

# %%
# Reading file
series = pd.read_csv("daily-total-female-births.csv", parse_dates = ["Date"], index_col=0)

# %%
series
# Out:
#             Births
# Date
# 1959-01-01      35
# 1959-01-02      32
# 1959-01-03      30
# 1959-01-04      31
# 1959-01-05      44
# ...            ...
# 1959-12-27      37
# 1959-12-28      52
# 1959-12-29      48
# 1959-12-30      55
# 1959-12-31      50
#
# [365 rows x 1 columns]

# %% [markdown]
# ## Plotting Time series data

# %%
fig, ax = plt.subplots()
ax.plot(series)

ax.set(xlabel='Date', ylabel='Birth',
       title='Stationary Series')

plt.show()

# %% [markdown]
# ## Performing Adfuller Test

# %%
result = adfuller(series)
print("P-value :", result[1])
print("AD Fuller Statistic : %f" % result[0])
print("Crictical Values")
for key, value in result[4].items():
    print("\t",key,": %.2f" % (value))
# Out:
# P-value : 5.2434129901498554e-05
# AD Fuller Statistic : -4.808291
# Crictical Values
# 	 1% : -3.45
# 	 5% : -2.87
# 	 10% : -2.57

# %% [markdown]
# As we can see,
# 1) The value is less than 0.05 has we can reject the null hypothesis. Concluding the given series in stationary.
# 2) statiscal value is less than critical value. we can reject the null hypothesis. Concluding the given series in stationary.

# %% [markdown]
# # Non Stationary Series

# %%
# Reading file
series1 = pd.read_csv("airline-passengers.csv", index_col=0, parse_dates = ["Month"])

# %%
series1
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %% [markdown]
# ## Plotting Time series data

# %%
fig, ax = plt.subplots()
ax.plot(series1)

ax.set(xlabel='Month', ylabel='Passengers',
       title='Non-Stationary Series')

plt.show()

# %% [markdown]
# ## Performing Adfuller Test

# %%
result = adfuller(series1)
print("P-value :", result[1])
print("AD Fuller Statistic : %f" % result[0])
print("Crictical Values")
for key, value in result[4].items():
    print("\t",key,": %.2f" % (value))
# Out:
# P-value : 0.9918802434376409
# AD Fuller Statistic : 0.815369
# Crictical Values
# 	 1% : -3.48
# 	 5% : -2.88
# 	 10% : -2.58

# %% [markdown]
# # Differencing

# %%
from datetime import datetime

dateparse = lambda x : datetime.strptime("190" + x, '%Y-%m')
series2 = pd.read_csv("shampoo_sales.csv",parse_dates=["Month"],  index_col=0 , date_parser=dateparse)
# Out:
# /var/folders/_m/_0hzmbf1467gxwxv0b95v6_80000gn/T/ipykernel_17368/3042355774.py:4: FutureWarning: The argument 'date_parser' is deprecated and will be removed in a future version. Please use 'date_format' instead, or read your data in as 'object' dtype and then call 'to_datetime'.
#   series2 = pd.read_csv("shampoo_sales.csv",parse_dates=["Month"],  index_col=0 , date_parser=dateparse)

# %%
series2
# Out:
#             Sales
# Month
# 1901-01-01  266.0
# 1901-02-01  145.9
# 1901-03-01  183.1
# 1901-04-01  119.3
# 1901-05-01  180.3
# 1901-06-01  168.5
# 1901-07-01  231.8
# 1901-08-01  224.5
# 1901-09-01  192.8
# 1901-10-01  122.9
# 1901-11-01  336.5
# 1901-12-01  185.9
# 1902-01-01  194.3
# 1902-02-01  149.5
# 1902-03-01  210.1
# 1902-04-01  273.3
# 1902-05-01  191.4
# 1902-06-01  287.0
# 1902-07-01  226.0
# 1902-08-01  303.6
# 1902-09-01  289.9
# 1902-10-01  421.6
# 1902-11-01  264.5
# 1902-12-01  342.3
# 1903-01-01  339.7
# 1903-02-01  440.4
# 1903-03-01  315.9
# 1903-04-01  439.3
# 1903-05-01  401.3
# 1903-06-01  437.4
# 1903-07-01  575.5
# 1903-08-01  407.6
# 1903-09-01  682.0
# 1903-10-01  475.3
# 1903-11-01  581.3
# 1903-12-01  646.9

# %%
fig, ax = plt.subplots()
ax.plot(series2)


ax.set(xlabel='Month', ylabel='Sales',
       title='Non-Stationary Series')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## First order difference

# %%
# Performing first order differencing
series3 = series2.diff()
series3 = series3[1:]
series3
# Out:
#             Sales
# Month
# 1901-02-01 -120.1
# 1901-03-01   37.2
# 1901-04-01  -63.8
# 1901-05-01   61.0
# 1901-06-01  -11.8
# 1901-07-01   63.3
# 1901-08-01   -7.3
# 1901-09-01  -31.7
# 1901-10-01  -69.9
# 1901-11-01  213.6
# 1901-12-01 -150.6
# 1902-01-01    8.4
# 1902-02-01  -44.8
# 1902-03-01   60.6
# 1902-04-01   63.2
# 1902-05-01  -81.9
# 1902-06-01   95.6
# 1902-07-01  -61.0
# 1902-08-01   77.6
# 1902-09-01  -13.7
# 1902-10-01  131.7
# 1902-11-01 -157.1
# 1902-12-01   77.8
# 1903-01-01   -2.6
# 1903-02-01  100.7
# 1903-03-01 -124.5
# 1903-04-01  123.4
# 1903-05-01  -38.0
# 1903-06-01   36.1
# 1903-07-01  138.1
# 1903-08-01 -167.9
# 1903-09-01  274.4
# 1903-10-01 -206.7
# 1903-11-01  106.0
# 1903-12-01   65.6

# %%
fig, ax = plt.subplots()
ax.plot(series3)


ax.set(xlabel='Month', ylabel='Sales',
       title='Original Series after performing first order difference')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Second order difference

# %%
# Performing first order differencing
series4 = series3.diff()
series4 = series4[1:]

fig, ax = plt.subplots()
ax.plot(series4)

ax.set(xlabel='Month', ylabel='Sales',
       title='Original Series after performing Second order difference')

plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Seasonal Decomposition

# %%
import pandas as pd
import numpy as np
from statsmodels.tsa.seasonal import seasonal_decompose
from random import randrange
from pandas import Series
from matplotlib import pyplot
import matplotlib.pyplot as plt

# %%
s = [i+randrange(10) for i in range(1,100)]

# %% [markdown]
# # Plotting The Series

# %%
pd.Series(s).plot()
# Out:
# <Axes: >

# %% [markdown]
# # Additive

# %%
result = seasonal_decompose(s, model='additive', period=1)
result.plot()
pyplot.show()

# %% [markdown]
# # Multplicative

# %%
result = seasonal_decompose(s, model='multplicative', period=1)
result.plot()
pyplot.show()

# %% [markdown]
# # Decomposing with the wrong model

# %% [markdown]
# We can clearly see with the different peak height that means it a multiplicative series

# %%
# Reading file
series1 = pd.read_csv("airline-passengers.csv", index_col=0, parse_dates = ["Month"])
series1.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
series1
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %% [markdown]
# Period is taken 12 as one record is for one month, We want to see it in the annually

# %%
result1 = seasonal_decompose(series1["Passengers"], model='additive', period=12)
result1.plot()
pyplot.show()

# %%
result1.trend.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
result1.seasonal.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
result1.resid.plot()
# Out:
# <Axes: xlabel='Month'>

# %%
result2 = seasonal_decompose(series1["Passengers"], model='multiplicative', period=12)
result2.plot()
pyplot.show()

# %%
# Single season multiplier factors - for seasonality effect
xs = np.arange(1, 121)
seasonal_multipliers = [110, 130, 120, 150, 190, 230, 210, 280, 200, 170, 150, 120]
# Immitate 10 years of data
x_range = np.arange(1, 121)
# Raise to the 1.25 power to get upwards "curved" trend
x_range = np.array([x**1.25 for x in xs])

time_series = []
# Split to 10 chunks - 1 year each
for chunk in np.split(x_range, 10):
    for i, val in enumerate(chunk):
        # Multiply value with seasonal scalar
        time_series.append(val * seasonal_multipliers[i])
        
# Convert to DataFrame
df_mm = pd.DataFrame(
    data={'y': time_series}, 
    index=pd.date_range(start='2010-01-01', freq='MS', periods=120)
)

# Plot
plt.title('Multiplicative trend and Multiplicative seasonality time series', size=20)
plt.plot(df_mm);

# %%
df_mm
# Out:
#                         y
# 2010-01-01     110.000000
# 2010-02-01     309.193850
# 2010-03-01     473.786645
# 2010-04-01     848.528137
# 2010-05-01    1420.581342
# ...                   ...
# 2019-08-01  106593.449774
# 2019-09-01   76959.515131
# 2019-10-01   66115.217429
# 2019-11-01   58955.586044
# 2019-12-01   47660.413243
#
# [120 rows x 1 columns]

# %%
decomposed = seasonal_decompose(df_mm, model='additive')
decomposed.plot();

# %%
decomposed = seasonal_decompose(df_mm, model='multiplicative')
decomposed.plot();
